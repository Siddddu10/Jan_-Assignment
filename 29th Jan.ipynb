# %%
'''
Q1.Who developed Python Programming language

Ans-
Python programming language was developed by Guido van Rossum in the late 1980s while he was
working at the National Research Institute for Mathematics and Computer Science in the 
Netherlands.

Q2.Who developed Python Programming language

Ans-Python is a general-purpose programming language that supports several programming paradigms,
including:

1)Procedural programming: Writing programs using a series of procedures or functions that are 
executed in a specific order to perform a specific task.
2)Object-oriented programming (OOP): Writing programs using objects that interact with each
other to perform a specific task.
3)Functional programming: Writing programs using functions that are treated as first-class 
citizens, meaning they can be passed as arguments to other functions and returned as values.
4)Aspect-oriented programming (AOP): Writing programs using aspects that modify the behavior of
other parts of the program.

Q3.Is Python case sensitive when dealing with identifiers

Ans-Yes, Python is a case-sensitive programming language when dealing with identifiers such as
variable names, function names, class names, and module names. This means that identifiers with
different capitalization are considered to be different and separate from each other.

Q4.What is a correct extension python file

Ans-In Python, the correct file extension for a Python source code file is .py.This is the
standard file extension used by Python, and it is recognized by most Python development tools 
and environments.

Q5.Is python code compiled or interpreted

Ans-Python is an interpreted programming language, which means that Python code is executed 
directly by an interpreter, line by line, without the need for compilation to machine code.

Q6.Name a few blocks of code used to define in python language

Ans-In Python, you can define blocks of code using indentation. The most common types of blocks in Python are:

1)Function blocks: These are blocks of code that define a function. They start with the def 
keyword and are followed by the function name and its arguments, and a colon. The code inside 
the function block is indented and defines the behavior of the function
2)Loop blocks: These are blocks of code that define loops. They can be created using the for or
while keywords followed by a colon. The code inside the loop block is indented and is executed 
repeatedly as long as the loop condition is true.
3)Conditional blocks: These are blocks of code that define conditional statements. They can be 
created using the if, elif, and else keywords followed by a colon. The code inside the 
conditional block is indented and is executed only if the condition is true.

Q7.State a character used to give single line comments in python

Ans-#

Q8.Mention function which can help us to find the version of python we are currently working on
Ans-sys.version

Q9.Pythons supports the creation of anonymous function at runtime using a construct called 
"Lambda Function"

Q10.What does pip stand for

Ans-In Python, pip stands for "Pip Installs Packages". 

Q11.Mention a few built in functions in python

Ans-Here are some of the most commonly used built-in functions in Python:

print(): Prints the specified message to the console.

len(): Returns the length (number of items) of an object.

type(): Returns the type of an object.

range(): Generates a sequence of numbers.

input(): Accepts input from the user and returns it as a string.

str(): Converts an object to a string.

int(): Converts a string or other object to an integer.

float(): Converts a string or other object to a floating-point number.

bool(): Converts an object to a Boolean value.

list(): Converts an object to a list.

dict(): Creates a new dictionary.

set(): Creates a new set.

tuple(): Converts an object to a tuple.

abs(): Returns the absolute value of a number.

max(): Returns the largest item in an iterable.

min(): Returns the smallest item in an iterable.

sum(): Returns the sum of all items in an iterable.

sorted(): Returns a sorted list of items from an iterable.

enumerate(): Returns an iterator of tuples containing indices and values from an iterable.

zip(): Returns an iterator of tuples, where the i-th tuple contains the i-th element from each of the input iterables.

Q12.What is maximum possible length of an identifier in python

Ans-
In Python, the maximum length of an identifier (variable name, function name, etc.)
is not specified, but it is practical to limit the length of identifiers to 79 characters

Q13.What are the benifits of using Python

Ans-Here are some of the key benefits of using Python:

1)Easy to learn and use: Python has a simple, intuitive syntax that is easy to learn and use, 
even for beginners. Its clean, readable code makes it easy to maintain and modify over time.

2)Large community and ecosystem: Python has a large, active community of developers and users
who contribute to its development, share knowledge and resources, and create a wide range of 
libraries and tools for a variety of applications.

3)Cross-platform compatibility: Python is a cross-platform language that can run on almost any 
operating system, including Windows, macOS, and Linux. This makes it easy to develop and deploy
applications across multiple platforms.

4)High-level language: Python is a high-level language that allows developers to focus on 
solving problems and building applications, rather than worrying about low-level details like
memory management and pointer arithmetic.

5)Rich library support: Python has a vast standard library that provides support for a wide 
range of programming tasks, from web development and data analysis to machine learning and
artificial intelligence.

6)Open-source: Python is an open-source language, meaning that its source code is freely 
available to anyone to use, modify, and distribute. This encourages collaboration and innovation
within the developer community.

7)Scalability: Python is scalable and can be used to build applications of any size and
complexity, from small scripts and utilities to large-scale enterprise applications.

Q14.How is the memory managed in Python

Ans-Python uses an automatic memory management system called "garbage collection" to manage 
memory allocation and deallocation

Q15.How to install python on windows and set path variables

Ans-

Q16.Is Indentation requires in python
Ans- Yes
